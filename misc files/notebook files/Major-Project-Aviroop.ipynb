# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk) (4.67.0)
# Requirement already satisfied: colorama in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from click->nltk) (0.4.6)

# %%
# !pip install gensim.models
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement gensim.models (from versions: none)
# ERROR: No matching distribution found for gensim.models

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\aviro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (3.5.0)

# %%
import pandas as pd
from gensim.models import Word2Vec
import nltk
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\aviro\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
df = pd.read_csv('datasets/linux/Linux_2k.log_structured.csv')
df.head()
# Out:
#    LineId Month  Date      Time  Level       Component      PID  \
# 0       1   Jun    14  15:16:01  combo  sshd(pam_unix)  19939.0
# 1       2   Jun    14  15:16:02  combo  sshd(pam_unix)  19937.0
# 2       3   Jun    14  15:16:02  combo  sshd(pam_unix)  19937.0
# 3       4   Jun    15  02:04:59  combo  sshd(pam_unix)  20882.0
# 4       5   Jun    15  02:04:59  combo  sshd(pam_unix)  20884.0
#
#                                              Content EventId  \
# 0  authentication failure; logname= uid=0 euid=0 ...     E16
# 1                           check pass; user unknown     E27
# 2  authentication failure; logname= uid=0 euid=0 ...     E16
# 3  authentication failure; logname= uid=0 euid=0 ...     E18
# 4  authentication failure; logname= uid=0 euid=0 ...     E18
#
#                                        EventTemplate
# 0  authentication failure; logname= uid=0 euid=0 ...
# 1                           check pass; user unknown
# 2  authentication failure; logname= uid=0 euid=0 ...
# 3  authentication failure; logname= uid=0 euid=0 ...
# 4  authentication failure; logname= uid=0 euid=0 ...

# %%
null_data = df.isnull().sum()

# %%
print(null_data[null_data > 0])
# Out:
# PID    151
# dtype: int64

# %%
df['Tokens'] = df['Content'].apply(word_tokenize)
df.head()
# Out:
#    LineId Month  Date      Time  Level       Component      PID  \
# 0       1   Jun    14  15:16:01  combo  sshd(pam_unix)  19939.0
# 1       2   Jun    14  15:16:02  combo  sshd(pam_unix)  19937.0
# 2       3   Jun    14  15:16:02  combo  sshd(pam_unix)  19937.0
# 3       4   Jun    15  02:04:59  combo  sshd(pam_unix)  20882.0
# 4       5   Jun    15  02:04:59  combo  sshd(pam_unix)  20884.0
#
#                                              Content EventId  \
# 0  authentication failure; logname= uid=0 euid=0 ...     E16
# 1                           check pass; user unknown     E27
# 2  authentication failure; logname= uid=0 euid=0 ...     E16
# 3  authentication failure; logname= uid=0 euid=0 ...     E18
# 4  authentication failure; logname= uid=0 euid=0 ...     E18
#
#                                        EventTemplate  \
# 0  authentication failure; logname= uid=0 euid=0 ...
# 1                           check pass; user unknown
# 2  authentication failure; logname= uid=0 euid=0 ...
# 3  authentication failure; logname= uid=0 euid=0 ...
# 4  authentication failure; logname= uid=0 euid=0 ...
#
#                                               tokens  TimeInSeconds  \
# 0  [authentication, failure, ;, logname=, uid=0, ...          54961
# 1                    [check, pass, ;, user, unknown]          54962
# 2  [authentication, failure, ;, logname=, uid=0, ...          54962
# 3  [authentication, failure, ;, logname=, uid=0, ...           7499
# 4  [authentication, failure, ;, logname=, uid=0, ...           7499
#
#                                               Tokens
# 0  [authentication, failure, ;, logname=, uid=0, ...
# 1                    [check, pass, ;, user, unknown]
# 2  [authentication, failure, ;, logname=, uid=0, ...
# 3  [authentication, failure, ;, logname=, uid=0, ...
# 4  [authentication, failure, ;, logname=, uid=0, ...

# %%
from sklearn.preprocessing import LabelEncoder

# Prepare your tokenized sentences
sentences = df['tokens'].values.tolist()

# Flatten the list of tokenized words
words = [word for sentence in sentences for word in sentence]

# Convert words to numeric labels
label_encoder = LabelEncoder()
X = label_encoder.fit_transform(words)

# Reshape X for the HMM
X = X.reshape(-1, 1)
X = X.tolist()
##print(X)
lab = dict(zip(words, X))
print(lab)
# Out:
# {'authentication': [411], 'failure': [467], ';': [261], 'logname=': [511], 'uid=0': [661], 'euid=0': [463], 'tty=NODEVssh': [659], 'ruser=': [624], 'rhost=218.188.2.4': [591], 'check': [432], 'pass': [543], 'user': [669], 'unknown': [663], 'rhost=220-135-151-1.hinet-ip.hinet.net': [594], 'user=root': [671], 'session': [633], 'opened': [537], 'for': [471], 'cyrus': [446], 'by': [422], '(': [6], ')': [7], 'closed': [434], 'ALERT': [266], 'exited': [465], 'abnormally': [394], 'with': [682], '[': [391], '1': [66], ']': [392], 'news': [529], 'rhost=061092085098.ctinets.com': [570], 'rhost=d211-116-254-214.rev.krline.net': [609], 'connection': [441], 'from': [474], '24.54.76.216': [216], '24-54-76-216.bflony.adelphia.net': [215], 'at': [408], 'Fri': [306], 'Jun': [323], '17': [147], '07:07:00': [46], '2005': [170], '07:07:02': [47], '07:07:04': [48], 'rhost=211.46.224.253': [586], 'user=guest': [670], 'test': [647], 'uid=509': [662], '82.252.162.81': [252], 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net': [509], '20:55:06': [177], '20:55:07': [178], 'rhost=adsl-70-242-75-179.dsl.ksc2mo.swbell.net': [604], 'Sat': [366], '18': [150], '02:08:10': [27], '02:08:11': [28], '02:08:12': [29], 'User': [384], 'timed': [650], 'out': [539], 'after': [399], '900': [259], 'seconds': [629], '02:23:10': [30], 'cupsd': [445], 'shutdown': [634], 'succeeded': [641], 'startup': [639], 'restart': [565], '.': [11], '222.33.90.199': [202], 'Mon': [336], '20': [164], '03:40:59': [36], 'Received': [358], 'SNMP': [364], 'packet': [540], 's': [625], '67.170.148.126': [241], 'rhost=65.166.159.14': [600], 'rhost=217.60.212.66': [589], 'rhost=n219076184117.netvigator.com': [613], 'rhost=ip-216-69-169-168.ip.secureserver.net': [611], '210.245.165.136': [182], 'Wed': [389], '22': [199], '13:16:30': [112], '13:16:31': [113], '13:16:32': [114], 'rhost=209.152.168.249': [579], 'rhost=200.60.37.201': [574], 'rhost=218.22.3.51': [592], '218.69.108.57': [195], '24': [214], '18:55:11': [153], '18:55:18': [154], 'rhost=massive.merukuru.org': [612], '210.118.170.95': [180], '25': [217], '09:20:24': [59], '211.167.68.59': [184], '19:25:30': [155], '19:25:31': [156], '19:25:34': [157], 'rhost=troi.bluesky-technologies.com': [615], 'rhost=61.53.154.93': [598], 'rhost=62-192-102-94.dsl.easynet.nl': [599], 'rhost=211.115.206.155': [583], '61.74.96.178': [236], '29': [222], '03:22:22': [32], '03:22:23': [33], 'rhost=csnsu.nsuok.edu': [608], '208.62.55.75': [176], '10:48:01': [74], '10:48:05': [75], '10:48:06': [76], '10:48:08': [77], '10:48:10': [78], '10:48:12': [79], '10:48:13': [80], '10:48:15': [81], '10:48:17': [82], '10:48:18': [83], '10:48:20': [84], '10:48:21': [85], 'rhost=h64-187-1-131.gtconnect.net': [610], '210.223.97.117': [181], '14:44:35': [136], 'rhost=biblioteka.wsi.edu.pl': [605], 'rhost=60.30.224.116': [596], 'rhost=195.129.24.210': [573], 'Authentication': [270], 'failed': [466], '163.27.187.39': [143], ':': [260], 'Permission': [350], 'denied': [450], 'in': [491], 'replay': [561], 'cache': [426], 'code': [435], 'Kerberos': [324], 'Software': [371], 'caused': [431], 'abort': [395], '202.82.200.188': [171], 'Jul': [322], '07:57:30': [51], 'rhost=zummit.com': [616], '203.101.45.59': [172], 'dsl-Chn-static-059.45.101.203.touchtelindia.net': [457], 'Sun': [374], '3': [223], '10:05:25': [73], '62.99.164.82': [237], '62.99.164.82.sh.interxion.inode.at': [238], '23:16:09': [208], 'rhost=210.76.59.29': [581], '63.197.98.106': [239], 'adsl-63-197-98-106.dsl.mtry01.pacbell.net': [398], '4': [229], '12:52:44': [109], 'rhost=220.117.241.87': [595], 'rhost=210.229.150.228': [580], '211.72.2.106': [188], 'Tue': [382], '5': [232], '13:52:21': [119], '13:52:23': [120], 'rhost=218.16.122.48': [590], '211.72.151.162': [187], '6': [235], '18:00:56': [151], '18:00:57': [152], '*': [8], 'info': [492], 'mice.c': [520], '1766': [149], 'imps2': [490], 'Auto-detected': [271], 'intellimouse': [497], 'PS/2': [348], 'root': [618], 'LOGIN': [329], 'ROOT': [356], 'ON': [342], 'tty2': [657] ...

# %%
# Convert Time to seconds for easier grouping
def time_to_seconds(time_str):
    h, m, s = map(int, time_str.split(":"))
    return h * 3600 + m * 60 + s

# Helper function to convert seconds to hh:mm:ss
def seconds_to_hms(seconds):
    h = seconds // 3600
    m = (seconds % 3600) // 60
    s = seconds % 60
    return f"{h:02}:{m:02}:{s:02}"

df['TimeInSeconds'] = df['Time'].apply(time_to_seconds)

# Step 4: Group Logs into Sequences by Time Window and Day
time_window = 5  # Define the time window in seconds
sequences = []
time_frames = []  # To store time frames for each sequence
current_sequence = []
current_start_time = None  # Track the start time of the current sequence
prev_time = None
prev_date = None
prev_month = None

for _, row in df.iterrows():
    is_same_day = (
        prev_date == row["Date"] and prev_month == row["Month"]
    )  # Check if the log is on the same day
    
    if (
        prev_time is None
        or (row["TimeInSeconds"] - prev_time <= time_window and is_same_day)
    ):
        if current_start_time is None:
            current_start_time = f"{row['Month']} {row['Date']} {row['Time']}"  # Start time of the new sequence
        current_sequence.append(row["Tokens"])
        prev_time = row["TimeInSeconds"]  # Update prev_time within the sequence
    else:
        sequences.append(current_sequence)
        end_time_hms = seconds_to_hms(prev_time)  # Convert end time to hh:mm:ss
        time_frames.append((current_start_time, f"{prev_month} {prev_date} {end_time_hms}"))  # Add time frame
        current_sequence = [row["Tokens"]]
        current_start_time = f"{row['Month']} {row['Date']} {row['Time']}"  # Reset the start time
        prev_time = row["TimeInSeconds"]  # Reset prev_time for the new sequence
    prev_date = row["Date"]
    prev_month = row["Month"]

# Add the last sequence and its time frame
if current_sequence:
    end_time_hms = seconds_to_hms(prev_time)
    time_frames.append((current_start_time, f"{prev_month} {prev_date} {end_time_hms}"))
    sequences.append(current_sequence)

# Visualization: Structured display with time frames
for i, (sequence, time_frame) in enumerate(zip(sequences, time_frames)):
    print(f"Sequence {i + 1} (Time Frame: {time_frame[0]} to {time_frame[1]}):")
    for log in sequence:
        print(f"  - {log}")
    print("\n")
# Out:
# Sequence 1 (Time Frame: Jun 14 15:16:01 to Jun 14 15:16:02):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.188.2.4']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.188.2.4']
#
#
# Sequence 2 (Time Frame: Jun 15 02:04:59 to Jun 15 02:04:59):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=220-135-151-1.hinet-ip.hinet.net', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=220-135-151-1.hinet-ip.hinet.net', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=220-135-151-1.hinet-ip.hinet.net', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=220-135-151-1.hinet-ip.hinet.net', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=220-135-151-1.hinet-ip.hinet.net', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=220-135-151-1.hinet-ip.hinet.net', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=220-135-151-1.hinet-ip.hinet.net', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=220-135-151-1.hinet-ip.hinet.net', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=220-135-151-1.hinet-ip.hinet.net', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=220-135-151-1.hinet-ip.hinet.net', 'user=root']
#
#
# Sequence 3 (Time Frame: Jun 15 04:06:18 to Jun 15 04:06:20):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 4 (Time Frame: Jun 15 04:12:42 to Jun 15 04:12:43):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 5 (Time Frame: Jun 15 12:12:34 to Jun 15 12:12:34):
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.188.2.4']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.188.2.4']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.188.2.4']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.188.2.4']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.188.2.4']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.188.2.4']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.188.2.4']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.188.2.4']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.188.2.4']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.188.2.4']
#
#
# Sequence 6 (Time Frame: Jun 15 12:13:19 to Jun 15 12:13:20):
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.188.2.4']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.188.2.4']
#
#
# Sequence 7 (Time Frame: Jun 15 14:53:32 to Jun 15 14:53:36):
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=061092085098.ctinets.com']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=061092085098.ctinets.com']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=061092085098.ctinets.com']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=061092085098.ctinets.com']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=061092085098.ctinets.com']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=061092085098.ctinets.com']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=061092085098.ctinets.com']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=061092085098.ctinets.com']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=061092085098.ctinets.com']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=061092085098.ctinets.com']
#
#
# Sequence 8 (Time Frame: Jun 15 20:05:31 to Jun 15 20:05:31):
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=d211-116-254-214.rev.krline.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=d211-116-254-214.rev.krline.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=d211-116-254-214.rev.krline.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=d211-116-254-214.rev.krline.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=d211-116-254-214.rev.krline.net']
#
#
# Sequence 9 (Time Frame: Jun 16 04:10:22 to Jun 16 04:10:24):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 10 (Time Frame: Jun 16 04:16:17 to Jun 16 04:16:18):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 11 (Time Frame: Jun 17 04:03:33 to Jun 17 04:03:36):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 12 (Time Frame: Jun 17 04:09:43 to Jun 17 04:09:45):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 13 (Time Frame: Jun 17 07:07:00 to Jun 17 07:07:04):
#   - ['connection', 'from', '24.54.76.216', '(', '24-54-76-216.bflony.adelphia.net', ')', 'at', 'Fri', 'Jun', '17', '07:07:00', '2005']
#   - ['connection', 'from', '24.54.76.216', '(', '24-54-76-216.bflony.adelphia.net', ')', 'at', 'Fri', 'Jun', '17', '07:07:00', '2005']
#   - ['connection', 'from', '24.54.76.216', '(', '24-54-76-216.bflony.adelphia.net', ')', 'at', 'Fri', 'Jun', '17', '07:07:00', '2005']
#   - ['connection', 'from', '24.54.76.216', '(', '24-54-76-216.bflony.adelphia.net', ')', 'at', 'Fri', 'Jun', '17', '07:07:00', '2005']
#   - ['connection', 'from', '24.54.76.216', '(', '24-54-76-216.bflony.adelphia.net', ')', 'at', 'Fri', 'Jun', '17', '07:07:00', '2005']
#   - ['connection', 'from', '24.54.76.216', '(', '24-54-76-216.bflony.adelphia.net', ')', 'at', 'Fri', 'Jun', '17', '07:07:00', '2005']
#   - ['connection', 'from', '24.54.76.216', '(', '24-54-76-216.bflony.adelphia.net', ')', 'at', 'Fri', 'Jun', '17', '07:07:02', '2005']
#   - ['connection', 'from', '24.54.76.216', '(', '24-54-76-216.bflony.adelphia.net', ')', 'at', 'Fri', 'Jun', '17', '07:07:04', '2005']
#
#
# Sequence 14 (Time Frame: Jun 17 19:43:13 to Jun 17 19:43:13):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=211.46.224.253', 'user=guest']
#
#
# Sequence 15 (Time Frame: Jun 17 20:29:26 to Jun 17 20:29:26):
#   - ['session', 'opened', 'for', 'user', 'test', 'by', '(', 'uid=509', ')']
#
#
# Sequence 16 (Time Frame: Jun 17 20:34:57 to Jun 17 20:34:57):
#   - ['session', 'closed', 'for', 'user', 'test']
#
#
# Sequence 17 (Time Frame: Jun 17 20:55:06 to Jun 17 20:55:07):
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Fri', 'Jun', '17', '20:55:06', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Fri', 'Jun', '17', '20:55:06', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Fri', 'Jun', '17', '20:55:06', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Fri', 'Jun', '17', '20:55:06', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Fri', 'Jun', '17', '20:55:06', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Fri', 'Jun', '17', '20:55:07', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Fri', 'Jun', '17', '20:55:07', '2005']
#
#
# Sequence 18 (Time Frame: Jun 18 01:30:59 to Jun 18 01:30:59):
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=adsl-70-242-75-179.dsl.ksc2mo.swbell.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=adsl-70-242-75-179.dsl.ksc2mo.swbell.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=adsl-70-242-75-179.dsl.ksc2mo.swbell.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=adsl-70-242-75-179.dsl.ksc2mo.swbell.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=adsl-70-242-75-179.dsl.ksc2mo.swbell.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=adsl-70-242-75-179.dsl.ksc2mo.swbell.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=adsl-70-242-75-179.dsl.ksc2mo.swbell.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=adsl-70-242-75-179.dsl.ksc2mo.swbell.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=adsl-70-242-75-179.dsl.ksc2mo.swbell.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=adsl-70-242-75-179.dsl.ksc2mo.swbell.net']
#
#
# Sequence 19 (Time Frame: Jun 18 02:08:10 to Jun 18 02:08:12):
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:10', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:10', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:10', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:10', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:10', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:10', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:10', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:11', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:11', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:11', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:11', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:11', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:12', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:12', '2005']
#   - ['connection', 'from', '82.252.162.81', '(', 'lns-vlq-45-tou-82-252-162-81.adsl.proxad.net', ')', 'at', 'Sat', 'Jun', '18', '02:08:12', '2005']
#
#
# Sequence 20 (Time Frame: Jun 18 02:23:10 to Jun 18 02:23:10):
#   - ['User', 'unknown', 'timed', 'out', 'after', '900', 'seconds', 'at', 'Sat', 'Jun', '18', '02:23:10', '2005']
#
#
# Sequence 21 (Time Frame: Jun 18 04:07:05 to Jun 18 04:07:06):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 22 (Time Frame: Jun 18 04:12:42 to Jun 18 04:12:43):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 23 (Time Frame: Jun 19 04:08:55 to Jun 19 04:09:02):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['cupsd', 'shutdown', 'succeeded']
#   - ['cupsd', 'startup', 'succeeded']
#
#
# Sequence 24 (Time Frame: Jun 19 04:09:11 to Jun 19 04:09:11):
#   - ['restart', '.']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 25 (Time Frame: Jun 19 04:15:18 to Jun 19 04:15:18):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 26 (Time Frame: Jun 20 03:40:59 to Jun 20 03:40:59):
#   - ['connection', 'from', '222.33.90.199', '(', ')', 'at', 'Mon', 'Jun', '20', '03:40:59', '2005']
#   - ['connection', 'from', '222.33.90.199', '(', ')', 'at', 'Mon', 'Jun', '20', '03:40:59', '2005']
#   - ['connection', 'from', '222.33.90.199', '(', ')', 'at', 'Mon', 'Jun', '20', '03:40:59', '2005']
#   - ['connection', 'from', '222.33.90.199', '(', ')', 'at', 'Mon', 'Jun', '20', '03:40:59', '2005']
#   - ['connection', 'from', '222.33.90.199', '(', ')', 'at', 'Mon', 'Jun', '20', '03:40:59', '2005']
#   - ['connection', 'from', '222.33.90.199', '(', ')', 'at', 'Mon', 'Jun', '20', '03:40:59', '2005']
#   - ['connection', 'from', '222.33.90.199', '(', ')', 'at', 'Mon', 'Jun', '20', '03:40:59', '2005']
#   - ['connection', 'from', '222.33.90.199', '(', ')', 'at', 'Mon', 'Jun', '20', '03:40:59', '2005']
#   - ['connection', 'from', '222.33.90.199', '(', ')', 'at', 'Mon', 'Jun', '20', '03:40:59', '2005']
#   - ['connection', 'from', '222.33.90.199', '(', ')', 'at', 'Mon', 'Jun', '20', '03:40:59', '2005']
#   - ['connection', 'from', '222.33.90.199', '(', ')', 'at', 'Mon', 'Jun', '20', '03:40:59', '2005']
#   - ['connection', 'from', '222.33.90.199', '(', ')', 'at', 'Mon', 'Jun', '20', '03:40:59', '2005']
#
#
# Sequence 27 (Time Frame: Jun 20 04:02:54 to Jun 20 04:02:55):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 28 (Time Frame: Jun 20 04:08:37 to Jun 20 04:08:38):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 29 (Time Frame: Jun 20 04:44:39 to Jun 20 04:44:39):
#   - ['Received', 'SNMP', 'packet', '(', 's', ')', 'from', '67.170.148.126']
#
#
# Sequence 30 (Time Frame: Jun 20 09:20:05 to Jun 20 09:20:08):
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=65.166.159.14']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=65.166.159.14']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=65.166.159.14']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=65.166.159.14']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=65.166.159.14']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=65.166.159.14']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=65.166.159.14']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=65.166.159.14']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=65.166.159.14']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=65.166.159.14']
#
#
# Sequence 31 (Time Frame: Jun 21 04:06:57 to Jun 21 04:06:59):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 32 (Time Frame: Jun 21 04:13:03 to Jun 21 04:13:04):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 33 (Time Frame: Jun 21 08:56:36 to Jun 21 08:56:36):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=217.60.212.66', 'user=guest']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=217.60.212.66', 'user=guest']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=217.60.212.66', 'user=guest']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=217.60.212.66', 'user=guest']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=217.60.212.66', 'user=guest']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=217.60.212.66', 'user=guest']
#
#
# Sequence 34 (Time Frame: Jun 22 03:17:26 to Jun 22 03:17:26):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#
#
# Sequence 35 (Time Frame: Jun 22 03:17:35 to Jun 22 03:17:36):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#
#
# Sequence 36 (Time Frame: Jun 22 03:17:45 to Jun 22 03:17:46):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#
#
# Sequence 37 (Time Frame: Jun 22 03:17:52 to Jun 22 03:17:56):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#
#
# Sequence 38 (Time Frame: Jun 22 03:18:02 to Jun 22 03:18:22):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=n219076184117.netvigator.com', 'user=root']
#
#
# Sequence 39 (Time Frame: Jun 22 04:05:58 to Jun 22 04:06:00):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 40 (Time Frame: Jun 22 04:11:42 to Jun 22 04:11:42):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 41 (Time Frame: Jun 22 04:30:55 to Jun 22 04:30:56):
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=ip-216-69-169-168.ip.secureserver.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=ip-216-69-169-168.ip.secureserver.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=ip-216-69-169-168.ip.secureserver.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=ip-216-69-169-168.ip.secureserver.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=ip-216-69-169-168.ip.secureserver.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=ip-216-69-169-168.ip.secureserver.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=ip-216-69-169-168.ip.secureserver.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=ip-216-69-169-168.ip.secureserver.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=ip-216-69-169-168.ip.secureserver.net']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=ip-216-69-169-168.ip.secureserver.net']
#
#
# Sequence 42 (Time Frame: Jun 22 13:16:30 to Jun 22 13:16:32):
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:30', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:31', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:31', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:31', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:31', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:31', '2005']
#   - ['connection', 'from', '210.245.165.136', '(', ')', 'at', 'Wed', 'Jun', '22', '13:16:32', '2005']
#
#
# Sequence 43 (Time Frame: Jun 23 01:41:29 to Jun 23 01:41:32):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=209.152.168.249', 'user=guest']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=209.152.168.249', 'user=guest']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=209.152.168.249', 'user=guest']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=209.152.168.249', 'user=guest']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=209.152.168.249', 'user=guest']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=209.152.168.249', 'user=guest']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=209.152.168.249', 'user=guest']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=209.152.168.249', 'user=guest']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=209.152.168.249', 'user=guest']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=209.152.168.249', 'user=guest']
#
#
# Sequence 44 (Time Frame: Jun 23 02:55:14 to Jun 23 02:55:14):
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=200.60.37.201']
#
#
# Sequence 45 (Time Frame: Jun 23 04:05:28 to Jun 23 04:05:30):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 46 (Time Frame: Jun 23 04:13:08 to Jun 23 04:13:09):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 47 (Time Frame: Jun 23 23:30:03 to Jun 23 23:30:05):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.22.3.51', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.22.3.51', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.22.3.51', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.22.3.51', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.22.3.51', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.22.3.51', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.22.3.51', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.22.3.51', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=218.22.3.51', 'user=root']
#
#
# Sequence 48 (Time Frame: Jun 24 04:05:34 to Jun 24 04:05:35):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 49 (Time Frame: Jun 24 04:11:12 to Jun 24 04:11:12):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 50 (Time Frame: Jun 24 18:55:11 to Jun 24 18:55:11):
#   - ['connection', 'from', '218.69.108.57', '(', ')', 'at', 'Fri', 'Jun', '24', '18:55:11', '2005']
#   - ['connection', 'from', '218.69.108.57', '(', ')', 'at', 'Fri', 'Jun', '24', '18:55:11', '2005']
#   - ['connection', 'from', '218.69.108.57', '(', ')', 'at', 'Fri', 'Jun', '24', '18:55:11', '2005']
#   - ['connection', 'from', '218.69.108.57', '(', ')', 'at', 'Fri', 'Jun', '24', '18:55:11', '2005']
#   - ['connection', 'from', '218.69.108.57', '(', ')', 'at', 'Fri', 'Jun', '24', '18:55:11', '2005']
#   - ['connection', 'from', '218.69.108.57', '(', ')', 'at', 'Fri', 'Jun', '24', '18:55:11', '2005']
#   - ['connection', 'from', '218.69.108.57', '(', ')', 'at', 'Fri', 'Jun', '24', '18:55:11', '2005']
#
#
# Sequence 51 (Time Frame: Jun 24 18:55:18 to Jun 24 18:55:18):
#   - ['connection', 'from', '218.69.108.57', '(', ')', 'at', 'Fri', 'Jun', '24', '18:55:18', '2005']
#   - ['connection', 'from', '218.69.108.57', '(', ')', 'at', 'Fri', 'Jun', '24', '18:55:18', '2005']
#   - ['connection', 'from', '218.69.108.57', '(', ')', 'at', 'Fri', 'Jun', '24', '18:55:18', '2005']
#   - ['connection', 'from', '218.69.108.57', '(', ')', 'at', 'Fri', 'Jun', '24', '18:55:18', '2005']
#   - ['connection', 'from', '218.69.108.57', '(', ')', 'at', 'Fri', 'Jun', '24', '18:55:18', '2005']
#   - ['connection', 'from', '218.69.108.57', '(', ')', 'at', 'Fri', 'Jun', '24', '18:55:18', '2005']
#
#
# Sequence 52 (Time Frame: Jun 25 04:04:25 to Jun 25 04:04:26):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 53 (Time Frame: Jun 25 04:10:34 to Jun 25 04:10:35):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 54 (Time Frame: Jun 25 04:41:49 to Jun 25 04:41:51):
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=massive.merukuru.org']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=massive.merukuru.org']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=massive.merukuru.org']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=massive.merukuru.org']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=massive.merukuru.org']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=massive.merukuru.org']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=massive.merukuru.org']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=massive.merukuru.org']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=massive.merukuru.org']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=massive.merukuru.org']
#
#
# Sequence 55 (Time Frame: Jun 25 09:20:24 to Jun 25 09:20:24):
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#   - ['connection', 'from', '210.118.170.95', '(', ')', 'at', 'Sat', 'Jun', '25', '09:20:24', '2005']
#
#
# Sequence 56 (Time Frame: Jun 25 19:25:30 to Jun 25 19:25:34):
#   - ['connection', 'from', '211.167.68.59', '(', ')', 'at', 'Sat', 'Jun', '25', '19:25:30', '2005']
#   - ['connection', 'from', '211.167.68.59', '(', ')', 'at', 'Sat', 'Jun', '25', '19:25:30', '2005']
#   - ['connection', 'from', '211.167.68.59', '(', ')', 'at', 'Sat', 'Jun', '25', '19:25:30', '2005']
#   - ['connection', 'from', '211.167.68.59', '(', ')', 'at', 'Sat', 'Jun', '25', '19:25:30', '2005']
#   - ['connection', 'from', '211.167.68.59', '(', ')', 'at', 'Sat', 'Jun', '25', '19:25:30', '2005']
#   - ['connection', 'from', '211.167.68.59', '(', ')', 'at', 'Sat', 'Jun', '25', '19:25:30', '2005']
#   - ['connection', 'from', '211.167.68.59', '(', ')', 'at', 'Sat', 'Jun', '25', '19:25:30', '2005']
#   - ['connection', 'from', '211.167.68.59', '(', ')', 'at', 'Sat', 'Jun', '25', '19:25:30', '2005']
#   - ['connection', 'from', '211.167.68.59', '(', ')', 'at', 'Sat', 'Jun', '25', '19:25:30', '2005']
#   - ['connection', 'from', '211.167.68.59', '(', ')', 'at', 'Sat', 'Jun', '25', '19:25:31', '2005']
#   - ['connection', 'from', '211.167.68.59', '(', ')', 'at', 'Sat', 'Jun', '25', '19:25:31', '2005']
#   - ['connection', 'from', '211.167.68.59', '(', ')', 'at', 'Sat', 'Jun', '25', '19:25:31', '2005']
#   - ['connection', 'from', '211.167.68.59', '(', ')', 'at', 'Sat', 'Jun', '25', '19:25:34', '2005']
#
#
# Sequence 57 (Time Frame: Jun 26 04:04:17 to Jun 26 04:04:24):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['cupsd', 'shutdown', 'succeeded']
#   - ['cupsd', 'startup', 'succeeded']
#
#
# Sequence 58 (Time Frame: Jun 26 04:04:31 to Jun 26 04:04:31):
#   - ['restart', '.']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 59 (Time Frame: Jun 26 04:10:02 to Jun 26 04:10:04):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 60 (Time Frame: Jun 27 04:02:47 to Jun 27 04:02:49):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 61 (Time Frame: Jun 27 04:08:56 to Jun 27 04:08:57):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 62 (Time Frame: Jun 27 08:05:37 to Jun 27 08:05:39):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=troi.bluesky-technologies.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=troi.bluesky-technologies.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=troi.bluesky-technologies.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=troi.bluesky-technologies.com', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=troi.bluesky-technologies.com', 'user=root']
#
#
# Sequence 63 (Time Frame: Jun 28 04:03:15 to Jun 28 04:03:17):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 64 (Time Frame: Jun 28 04:09:00 to Jun 28 04:09:01):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 65 (Time Frame: Jun 28 08:10:24 to Jun 28 08:10:30):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=61.53.154.93', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=61.53.154.93', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=61.53.154.93', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=61.53.154.93', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=61.53.154.93', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=61.53.154.93', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=61.53.154.93', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=61.53.154.93', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=61.53.154.93', 'user=root']
#
#
# Sequence 66 (Time Frame: Jun 28 20:58:46 to Jun 28 20:58:55):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=62-192-102-94.dsl.easynet.nl', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=62-192-102-94.dsl.easynet.nl', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=62-192-102-94.dsl.easynet.nl', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=62-192-102-94.dsl.easynet.nl', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=62-192-102-94.dsl.easynet.nl', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=62-192-102-94.dsl.easynet.nl', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=62-192-102-94.dsl.easynet.nl', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=62-192-102-94.dsl.easynet.nl', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=62-192-102-94.dsl.easynet.nl', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=62-192-102-94.dsl.easynet.nl', 'user=root']
#
#
# Sequence 67 (Time Frame: Jun 28 21:42:46 to Jun 28 21:42:46):
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=211.115.206.155']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=211.115.206.155']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=211.115.206.155']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=211.115.206.155']
#   - ['check', 'pass', ';', 'user', 'unknown']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=211.115.206.155']
#
#
# Sequence 68 (Time Frame: Jun 29 03:22:22 to Jun 29 03:22:23):
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
#   - ['connection', 'from', '61.74.96.178', '(', ')', 'at', 'Wed', 'Jun', '29', '03:22:22', '2005']
# ...
#   - ['warning', ':', 'ca', "n't", 'get', 'client', 'address', ':', 'Connection', 'reset', 'by', 'peer']
#   - ['getpeername', '(', 'ftpd', ')', ':', 'Transport', 'endpoint', 'is', 'not', 'connected']
#   - ['warning', ':', 'ca', "n't", 'get', 'client', 'address', ':', 'Connection', 'reset', 'by', 'peer']
#   - ['getpeername', '(', 'ftpd', ')', ':', 'Transport', 'endpoint', 'is', 'not', 'connected']
#
#
# Sequence 239 (Time Frame: Jul 25 23:24:09 to Jul 25 23:24:09):
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#   - ['connection', 'from', '217.187.83.50', '(', ')', 'at', 'Mon', 'Jul', '25', '23:24:09', '2005']
#
#
# Sequence 240 (Time Frame: Jul 26 04:05:22 to Jul 26 04:05:24):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 241 (Time Frame: Jul 26 04:11:23 to Jul 26 04:11:23):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 242 (Time Frame: Jul 26 05:47:42 to Jul 26 05:47:42):
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:42', '2005']
#
#
# Sequence 243 (Time Frame: Jul 26 05:47:51 to Jul 26 05:47:51):
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:51', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:51', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:51', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:51', '2005']
#   - ['connection', 'from', '172.181.208.156', '(', ')', 'at', 'Tue', 'Jul', '26', '05:47:51', '2005']
#
#
# Sequence 244 (Time Frame: Jul 26 07:02:27 to Jul 26 07:02:27):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#
#
# Sequence 245 (Time Frame: Jul 26 07:02:35 to Jul 26 07:02:37):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#
#
# Sequence 246 (Time Frame: Jul 26 07:02:45 to Jul 26 07:02:47):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#
#
# Sequence 247 (Time Frame: Jul 26 07:02:55 to Jul 26 07:02:57):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#
#
# Sequence 248 (Time Frame: Jul 26 07:03:05 to Jul 26 07:03:07):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#
#
# Sequence 249 (Time Frame: Jul 26 07:03:15 to Jul 26 07:03:17):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#
#
# Sequence 250 (Time Frame: Jul 26 07:03:26 to Jul 26 07:03:27):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#
#
# Sequence 251 (Time Frame: Jul 26 07:03:35 to Jul 26 07:03:37):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#
#
# Sequence 252 (Time Frame: Jul 26 07:03:45 to Jul 26 07:03:47):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#
#
# Sequence 253 (Time Frame: Jul 26 07:03:55 to Jul 26 07:04:12):
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#   - ['authentication', 'failure', ';', 'logname=', 'uid=0', 'euid=0', 'tty=NODEVssh', 'ruser=', 'rhost=207.243.167.114', 'user=root']
#
#
# Sequence 254 (Time Frame: Jul 27 04:16:07 to Jul 27 04:16:09):
#   - ['session', 'opened', 'for', 'user', 'cyrus', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'cyrus']
#   - ['ALERT', 'exited', 'abnormally', 'with', '[', '1', ']']
#
#
# Sequence 255 (Time Frame: Jul 27 04:21:39 to Jul 27 04:21:40):
#   - ['session', 'opened', 'for', 'user', 'news', 'by', '(', 'uid=0', ')']
#   - ['session', 'closed', 'for', 'user', 'news']
#
#
# Sequence 256 (Time Frame: Jul 27 10:59:53 to Jul 27 10:59:53):
#   - ['connection', 'from', '218.38.58.3', '(', ')', 'at', 'Wed', 'Jul', '27', '10:59:53', '2005']
#
#
# Sequence 257 (Time Frame: Jul 27 14:41:57 to Jul 27 14:42:00):
#   - ['restart', '.']
#   - ['syslogd', 'startup', 'succeeded']
#   - ['klogd', '1.4.1', ',', 'log', 'source', '=', '/proc/kmsg', 'started', '.']
#   - ['Linux', 'version', '2.6.5-1.358', '(', 'bhcompile', '@', 'bugs.build.redhat.com', ')', '(', 'gcc', 'version', '3.3.3', '20040412', '(', 'Red', 'Hat', 'Linux', '3.3.3-7', ')', ')', '#', '1', 'Sat', 'May', '8', '09:04:50', 'EDT', '2004']
#   - ['BIOS-provided', 'physical', 'RAM', 'map', ':']
#   - ['BIOS-e820', ':', '0000000000000000', '-', '00000000000a0000', '(', 'usable', ')']
#   - ['BIOS-e820', ':', '00000000000f0000', '-', '0000000000100000', '(', 'reserved', ')']
#   - ['BIOS-e820', ':', '0000000000100000', '-', '0000000007eae000', '(', 'usable', ')']
#   - ['BIOS-e820', ':', '0000000007eae000', '-', '0000000008000000', '(', 'reserved', ')']
#   - ['BIOS-e820', ':', '00000000ffb00000', '-', '0000000100000000', '(', 'reserved', ')']
#   - ['0MB', 'HIGHMEM', 'available', '.']
#   - ['126MB', 'LOWMEM', 'available', '.']
#   - ['zapping', 'low', 'mappings', '.']
#   - ['klogd', 'startup', 'succeeded']
#   - ['On', 'node', '0', 'totalpages', ':', '32430']
#   - ['DMA', 'zone', ':', '4096', 'pages', ',', 'LIFO', 'batch:1']
#   - ['Normal', 'zone', ':', '28334', 'pages', ',', 'LIFO', 'batch:6']
#   - ['irqbalance', 'startup', 'succeeded']
#   - ['HighMem', 'zone', ':', '0', 'pages', ',', 'LIFO', 'batch:1']
#   - ['DMI', '2.3', 'present', '.']
#   - ['ACPI', 'disabled', 'because', 'your', 'bios', 'is', 'from', '2000', 'and', 'too', 'old']
#   - ['You', 'can', 'enable', 'it', 'with', 'acpi=force']
#   - ['Built', '1', 'zonelists']
#   - ['Kernel', 'command', 'line', ':', 'ro', 'root=LABEL=/', 'rhgb', 'quiet']
#   - ['mapped', '4G/4G', 'trampoline', 'to', 'ffff3000', '.']
#   - ['Initializing', 'CPU', '#', '0']
#   - ['CPU', '0', 'irqstacks', ',', 'hard=02345000', 'soft=02344000']
#   - ['portmap', 'startup', 'succeeded']
#   - ['PID', 'hash', 'table', 'entries', ':', '512', '(', 'order', '9', ':', '4096', 'bytes', ')']
#   - ['Detected', '731.219', 'MHz', 'processor', '.']
#   - ['Version', '1.0.6', 'Starting']
#   - ['Using', 'tsc', 'for', 'high-res', 'timesource']
#   - ['rpc.statd', 'startup', 'succeeded']
#   - ['Console', ':', 'colour', 'VGA+', '80x25']
#   - ['Memory', ':', '125312k/129720k', 'available', '(', '1540k', 'kernel', 'code', ',', '3860k', 'reserved', ',', '599k', 'data', ',', '144k', 'init', ',', '0k', 'highmem', ')']
#   - ['Calibrating', 'delay', 'loop', '...', '1445.88', 'BogoMIPS']
#   - ['Security', 'Scaffold', 'v1.0.0', 'initialized']
#   - ['SELinux', ':', 'Initializing', '.']
#   - ['SELinux', ':', 'Starting', 'in', 'permissive', 'mode']
#   - ['There', 'is', 'already', 'a', 'security', 'framework', 'initialized', ',', 'register_security', 'failed', '.']
#   - ['Failure', 'registering', 'capabilities', 'with', 'the', 'kernel']
#   - ['selinux_register_security', ':', 'Registering', 'secondary', 'module', 'capability']
#   - ['Capability', 'LSM', 'initialized']
#   - ['rpc.idmapd', 'startup', 'succeeded']
#   - ['Dentry', 'cache', 'hash', 'table', 'entries', ':', '16384', '(', 'order', ':', '4', ',', '65536', 'bytes', ')']
#   - ['Inode-cache', 'hash', 'table', 'entries', ':', '8192', '(', 'order', ':', '3', ',', '32768', 'bytes', ')']
#   - ['Mount-cache', 'hash', 'table', 'entries', ':', '512', '(', 'order', ':', '0', ',', '4096', 'bytes', ')']
#   - ['CPU', ':', 'L1', 'I', 'cache', ':', '16K', ',', 'L1', 'D', 'cache', ':', '16K']
#   - ['CPU', ':', 'L2', 'cache', ':', '256K']
#   - ['Intel', 'machine', 'check', 'architecture', 'supported', '.']
#   - ['Intel', 'machine', 'check', 'reporting', 'enabled', 'on', 'CPU', '#', '0', '.']
#   - ['CPU', ':', 'Intel', 'Pentium', 'III', '(', 'Coppermine', ')', 'stepping', '06']
#   - ['Enabling', 'fast', 'FPU', 'save', 'and', 'restore', '...', 'done', '.']
#   - ['Enabling', 'unmasked', 'SIMD', 'FPU', 'exception', 'support', '...', 'done', '.']
#   - ['Checking', "'hlt", "'", 'instruction', '...', 'OK', '.']
#   - ['Initializing', 'random', 'number', 'generator', ':', 'succeeded']
#   - ['POSIX', 'conformance', 'testing', 'by', 'UNIFIX']
#   - ['NET', ':', 'Registered', 'protocol', 'family', '16']
#   - ['PCI', ':', 'PCI', 'BIOS', 'revision', '2.10', 'entry', 'at', '0xfc0ce', ',', 'last', 'bus=1']
#   - ['PCI', ':', 'Using', 'configuration', 'type', '1']
#   - ['mtrr', ':', 'v2.0', '(', '20020519', ')']
#   - ['ACPI', ':', 'Subsystem', 'revision', '20040326']
#   - ['ACPI', ':', 'Interpreter', 'disabled', '.']
#   - ['Linux', 'Plug', 'and', 'Play', 'Support', 'v0.97', '(', 'c', ')', 'Adam', 'Belay']
#   - ['Starting', 'pcmcia', ':', 'succeeded']
#   - ['usbcore', ':', 'registered', 'new', 'driver', 'usbfs']
#   - ['usbcore', ':', 'registered', 'new', 'driver', 'hub']
#   - ['ACPI', ':', 'ACPI', 'tables', 'contain', 'no', 'PCI', 'IRQ', 'routing', 'entries']
#   - ['PCI', ':', 'Invalid', 'ACPI-PCI', 'IRQ', 'routing', 'table']
#   - ['PCI', ':', 'Probing', 'PCI', 'hardware']
#   - ['PCI', ':', 'Probing', 'PCI', 'hardware', '(', 'bus', '00', ')']
#   - ['Transparent', 'bridge', '-', '0000:00:1e.0']
#   - ['PCI', ':', 'Using', 'IRQ', 'router', 'PIIX/ICH', '[', '8086/2410', ']', 'at', '0000:00:1f.0']
#   - ['apm', ':', 'BIOS', 'version', '1.2', 'Flags', '0x03', '(', 'Driver', 'version', '1.16ac', ')']
#   - ['audit', ':', 'initializing', 'netlink', 'socket', '(', 'disabled', ')']
#   - ['kernel.core_uses_pid', '=', '1']
#   - ['HCI', 'daemon', 'ver', '2.4', 'started']
#   - ['hcid', 'startup', 'succeeded']
#   - ['audit', '(', '1122475266.4294965305:0', ')', ':', 'initialized']
#   - ['Setting', 'network', 'parameters', ':', 'succeeded']
#   - ['sdpd', 'startup', 'succeeded']
#   - ['sdpd', 'v1.5', 'started']
#   - ['Total', 'HugeTLB', 'memory', 'allocated', ',', '0']
#   - ['Bringing', 'up', 'loopback', 'interface', ':', 'succeeded']
#   - ['VFS', ':', 'Disk', 'quotas', 'dquot_6.5.1']
#   - ['Dquot-cache', 'hash', 'table', 'entries', ':', '1024', '(', 'order', '0', ',', '4096', 'bytes', ')']
#   - ['SELinux', ':', 'Registering', 'netfilter', 'hooks']
#   - ['Initializing', 'Cryptographic', 'API']
#   - ['pci_hotplug', ':', 'PCI', 'Hot', 'Plug', 'PCI', 'Core', 'version', ':', '0.5']
#   - ['isapnp', ':', 'Scanning', 'for', 'PnP', 'cards', '...']
#   - ['isapnp', ':', 'No', 'Plug', '&', 'Play', 'device', 'found']
#   - ['Real', 'Time', 'Clock', 'Driver', 'v1.12']
#   - ['Linux', 'agpgart', 'interface', 'v0.100', '(', 'c', ')', 'Dave', 'Jones']
